# %% [markdown]
# # **Aula 1**

# %% [markdown]
# # Introduction

# %%
# Python Version
from platform import python_version
print('Python Version Using Here:', python_version())
# Out:
# Python Version Using Here: 3.7.14

# %% [markdown]
# # Numbers and Operations

# %% [markdown]
# # Press Shift + Enter to execute the code in a cell or press the Play button on left side

# %%
# Sum
4 + 4
# Out:
# 8

# %%
# Subtraction
4 - 3
# Out:
# 1

# %%
# Multiplication
3 * 3
# Out:
# 9

# %%
# Division
3 / 2
# Out:
# 1.5

# %%
# Exponentiation
4 ** 2
# Out:
# 16

# %%
# Modulus (Modulus is the remainder or integer "left over" after dividing one integer by another to produce an integer quotient)
10 % 3
# Out:
# 1

# %% [markdown]
# # Type of Function

# %%
type(5)
# Out:
# int

# %%
type(5.0)
# Out:
# float

# %%
a = 'I am a string'
type(a)
# Out:
# str

# %% [markdown]
# # Operations with float

# %%
3.1 + 6.4
# Out:
# 9.5

# %%
4 + 4.0
# Out:
# 8.0

# %%
4 + 4
# Out:
# 8

# %%
# Resulting is a float
4 / 2
# Out:
# 2.0

# %%
# Resulting is an integer
4 // 2
# Out:
# 2

# %%
4 / 3.0
# Out:
# 1.3333333333333333

# %%
4 // 3.0
# Out:
# 1.0

# %% [markdown]
# # Conversion

# %%
float(9)
# Out:
# 9.0

# %%
int(6.0)
# Out:
# 6

# %%
int(6.5)
# Out:
# 6

# %% [markdown]
# # Hexadecimal and Binary

# %%
hex(394)
# Out:
# '0x18a'

# %%
hex(217)
# Out:
# '0xd9'

# %%
bin(286)
# Out:
# '0b100011110'

# %%
bin(390)
# Out:
# '0b110000110'

# %% [markdown]
# # Functions abs, round e pow

# %%
# Return the absolute value
abs(-8)
# Out:
# 8

# %%
# Return the absolute value
abs(8)
# Out:
# 8

# %%
# Return the value rounding with two decimal places
round(3.14151922,2)
# Out:
# 3.14

# %%
# Exponentiation 4^2
pow(4,2)
# Out:
# 16

# %%
# Exponentiation 5^3
pow(5,3)
# Out:
# 125

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Variables and Operators

# %%
# Setting value 1 to the variable var_test
var_test = 1

# %%
# Printing the value of the variable
var_test
# Out:
# 1

# %%
# Printing the value of the variable
print(var_test)
# Out:
# 1

# %%
# Can't use variable that is not define. See the error message.
my_var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7f70398ca07b> in <module>
#       1 # Não podemos utilizar uma variável que não foi definida. Veja a mensagem de erro.
# ----> 2 my_var
#
# NameError: name 'my_var' is not defined

# %%
var_test = 2

# %%
var_test
# Out:
# 2

# %%
type(var_test)
# Out:
# int

# %%
var_test = 9.5

# %%
type(var_test)
# Out:
# float

# %%
x = 1

# %%
x
# Out:
# 1

# %% [markdown]
# ## Multiple Setting

# %%
person1, person2, person3 = "Maria", "José", "Tobias"

# %%
person1
# Out:
# 'Maria'

# %%
person2
# Out:
# 'José'

# %%
person3
# Out:
# 'Tobias'

# %%
fruit1 = fruit2 = fruit3 = "Orange"

# %%
fruit1
# Out:
# 'Orange'

# %%
fruit2
# Out:
# 'Orange'

# %%
# Watch out!!! Python is case-sensitive. The variable is fruit2, not Fruit2.
# Upper and lower letter makes differences naming variables.
Fruit2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-367296529b33> in <module>
#       1 # Watch out!!! Python is case-sensitive. The variable is fruit2, not Fruit2.
#       2 # Upper and lower letter makes differences naming variables.
# ----> 3 Fruit2
#
# NameError: name 'Fruit2' is not defined

# %% [markdown]
# ## You can use letters, numbers and underline (but can't start with numbers)

# %%
x1 = 50

# %%
x1
# Out:
# 50

# %%
# Error message, Python doesn't allow first letter be a number on a variable
1x = 50
# Out:
#   File "<ipython-input-23-33a7c2a39e57>", line 2
#     1x = 50
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Can't use reserved words with variables names
#
# ## False
# ## class
# ## finally
# ## is
# ## return
# ## None
# ## continue
# ## for
# ## lambda
# ## try
# ## True
# ## def
# ## from
# ## nonlocal
# ## while
# ## and
# ## del
# ## global
# ## not
# ## with
# ## as
# ## elif
# ## if
# ## or
# ## yield
# ## assert
# ## else
# ## import
# ## pass
# ## break
# ## except
# ## in
# ## raise

# %%
# Can't use reserved words naming variables
break = 1
# Out:
#   File "<ipython-input-24-e88ee5721a0c>", line 2
#     break = 1
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Using variables with others variables and math operators order

# %%
lengh = 2

# %%
height = 4

# %%
area = lengh * height

# %%
area
# Out:
# 8

# %%
perimeter = 2 * lengh + 2 * height

# %%
perimeter
# Out:
# 12

# %%
# The order is the same using on Math
perimeter = 2 * (lengh + 2)  * height

# %%
perimeter
# Out:
# 32

# %% [markdown]
# ## Using variables to do Math

# %%
age1 = 25

# %%
age2 = 35

# %%
age1 + age2
# Out:
# 60

# %%
age2 - age1
# Out:
# 10

# %%
age2 * age1
# Out:
# 875

# %%
age2 / age1
# Out:
# 1.4

# %%
age2 % age1
# Out:
# 10

# %% [markdown]
# # Concatenation of Variables

# %%
first = "Python"

# %%
second = "Coding"

# %%
fullJoin = first + " " + second # the " " add a space in between

# %%
fullJoin
# Out:
# 'Python Coding'

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
