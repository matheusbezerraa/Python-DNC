# %% [markdown]
# # **Aula 4**

# %% [markdown]
# ## Strings

# %% [markdown]
# ### Creating a String
# To do that you could use double or simple " or '

# %%
# Just 1 word
'Hi'
# Out:
# 'Hi'

# %%
# Phrase
'Creating a string'
# Out:
# 'Creating a string'

# %%
# Using ""
"We could use double \" to do that"
# Out:
# 'We could use double " to do that'

# %%
# Combining
"Testing strings in 'Python'"
# Out:
# "Testing strings in 'Python'"

# %% [markdown]
# ### Print a string

# %%
print ('Testing strings in Python')
# Out:
# Testing strings in Python

# %%
print ('Testing \nStrings \nin \nPython')
# Out:
# Testing
# Strings
# in
# Python

# %%
print ('\n')

# %% [markdown]
# ### Indexing Strings

# %%
# Setting a string
s = 'Learning coding in Python'

# %%
print(s)
# Out:
# Learning coding in Python

# %%
# 1st element of string. 
s[0]
# Out:
# 'L'

# %%
s[1]
# Out:
# 'e'

# %%
s[2]
# Out:
# 'a'

# %% [markdown]
# Using : to execute a slicing to read until a certain place

# %%
# Return all elements of a string, starting by position 1 until the end
s[1:]
# Out:
# 'earning coding in Python'

# %%
# Original is not modified
s
# Out:
# 'Learning coding in Python'

# %%
# Returns all till position 3
s[:3]
# Out:
# 'Lea'

# %%
s[:]
# Out:
# 'Learning coding in Python'

# %%
# Could use negative to get backwards.
s[-1]
# Out:
# 'n'

# %%
# Return all, except last letter
s[:-1]
# Out:
# 'Learning coding in Pytho'

# %% [markdown]
# We could using the index to slice a string in especifit parts (the standard is 1). Example, we could use 2 points in a line to get different results.

# %%
s[::1]
# Out:
# 'Learning coding in Python'

# %%
s[::2]
# Out:
# 'Lann oigi yhn'

# %%
s[::-1]
# Out:
# 'nohtyP ni gnidoc gninraeL'

# %% [markdown]
# ### Properties of Strings

# %%
s
# Out:
# 'Learning coding in Python'

# %%
# Join 2 strings
s + ' is a usefull way to get started on the world of coding!!!'
# Out:
# 'Learning coding in Python is a usefull way to get started on the world of coding!!!'

# %%
s = s + ' is a usefull way to get started on the world of coding!!!'

# %%
print(s)
# Out:
# Learning coding in Python is a usefull way to get started on the world of coding!!!

# %%
# We could use the multiply marker to make a repetition
letter = 'w'

# %%
letter * 3
# Out:
# 'www'

# %% [markdown]
# ### Built-in Functions with Strings

# %%
s
# Out:
# 'Learning coding in Python is a usefull way to get started on the world of coding!!!'

# %%
# Upper Case 
s.upper()
# Out:
# 'LEARNING CODING IN PYTHON IS A USEFULL WAY TO GET STARTED ON THE WORLD OF CODING!!!'

# %%
# Lower case
s.lower()
# Out:
# 'learning coding in python is a usefull way to get started on the world of coding!!!'

# %%
# Split by blank spaces (standard)
s.split()
# Out:
# ['Learning',
#  'coding',
#  'in',
#  'Python',
#  'is',
#  'a',
#  'usefull',
#  'way',
#  'to',
#  'get',
#  'started',
#  'on',
#  'the',
#  'world',
#  'of',
#  'coding!!!']

# %%
# Split in a specific way
s.split('y')
# Out:
# ['Learning coding in P',
#  'thon is a usefull wa',
#  ' to get started on the world of coding!!!']

# %% [markdown]
# ### More functions on String

# %%
s = 'welcome on Python universe'

# %%
s.capitalize()
# Out:
# 'Welcome on python universe'

# %%
s.count('e')
# Out:
# 4

# %%
s.find('w')
# Out:
# 0

# %%
s.center(50, 'P')
# Out:
# 'PPPPPPPPPPPPwelcome on Python universePPPPPPPPPPPP'

# %%
s.isalnum()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s.islower()
# Out:
# False

# %%
s.isspace()
# Out:
# False

# %%
s.endswith('o') #try the letter e
# Out:
# False

# %%
s.partition('n')
# Out:
# ('welcome o', 'n', ' Python universe')

# %% [markdown]
# ### Comparing Strings

# %%
print("Python" == "R")
# Out:
# False

# %%
print("Python" == "Python")
# Out:
# True

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## Lists

# %%
# Creating
listadomercado = ["ovos, farinha, leite, maças"]

# %%
# Printing
print(listadomercado)
# Out:
# ['ovos, farinha, leite, maças']

# %%
# Another one
listadomercado2 = ["ovos", "farinha", "leite", "maças"]

# %%
# Printing
print(listadomercado2)
# Out:
# ['ovos', 'farinha', 'leite', 'maças']

# %%
# Creating
lista3 = [12, 100, "Universidade"]

# %%
# Printing
print(lista3)
# Out:
# [12, 100, 'Universidade']

# %%
# Setting each term of the list to a variable
item1 = lista3[0]
item2 = lista3[1]
item3 = lista3[2]

# %%
# Printing the variables
print(item1, item2, item3)
# Out:
# 12 100 Universidade

# %% [markdown]
# ### Updating an item on the list

# %%
# Printing 1 item
listadomercado2[2]
# Out:
# 'leite'

# %%
# Updating
listadomercado2[2] = "chocolate"

# %%
# Printing updated list
listadomercado2
# Out:
# ['ovos', 'farinha', 'chocolate', 'maças']

# %% [markdown]
# ### Deleting an item

# %%
# Out of index. Can't delete the index that is outside the list
del listadomercado2[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-84d96cb799fe> in <module>
#       1 # Out of index. Não é possível deletar um item que não existe na lista
# ----> 2 del listadomercado2[4]
#
# IndexError: list assignment index out of range

# %%
# Deleting
del listadomercado2[3]

# %%
# Printing the new list
listadomercado2
# Out:
# ['ovos', 'farinha', 'chocolate']

# %% [markdown]
# ### List of list
# in Python is what we know by Matrix

# %%
# Creating a matrix
listas = [[1,2,3], [10,15,14], [10.1,8.7,2.3]]

# %%
# Printing
listas
# Out:
# [[1, 2, 3], [10, 15, 14], [10.1, 8.7, 2.3]]

# %%
# Setting an item to a variable
a = listas[0]

# %%
a
# Out:
# [1, 2, 3]

# %%
b = a[0]

# %%
b
# Out:
# 1

# %%
list1 = listas[1]

# %%
list1
# Out:
# [10, 15, 14]

# %%
valor_1_0 = list1[0]

# %%
valor_1_0
# Out:
# 10

# %%
valor_1_2 = list1[2]

# %%
valor_1_2
# Out:
# 14

# %%
list2 = listas[2]

# %%
list2
# Out:
# [10.1, 8.7, 2.3]

# %%
valor_2_0 = list2[0]

# %%
valor_2_0
# Out:
# 10.1

# %% [markdown]
# ### Operating lists

# %%
# Matrix
listas = [[1,2,3], [10,15,14], [10.1,8.7,2.3]]

# %%
listas
# Out:
# [[1, 2, 3], [10, 15, 14], [10.1, 8.7, 2.3]]

# %%
# Setting the variable a to the 1st item of the 1st list
a = listas[0][0]

# %%
a
# Out:
# 1

# %%
b = listas[1][2]

# %%
b
# Out:
# 14

# %%
c = listas[0][2] + 10

# %%
c
# Out:
# 13

# %%
d = 10

# %%
d
# Out:
# 10

# %%
e = d * listas[2][0]

# %%
e
# Out:
# 101.0

# %% [markdown]
# ### Concatenating lists

# %%
lista_s1 = [34, 32, 56]

# %%
lista_s1
# Out:
# [34, 32, 56]

# %%
lista_s2 = [21, 90, 51]

# %%
lista_s2
# Out:
# [21, 90, 51]

# %%
# Joining
lista_total = lista_s1 + lista_s2

# %%
lista_total
# Out:
# [34, 32, 56, 21, 90, 51]

# %% [markdown]
# ## Operator in

# %%
# List
lista_teste_op = [100, 2, -5, 3.4]

# %%
# Checking if 10 is on
print(10 in lista_teste_op)
# Out:
# False

# %%
# Cheking if 100 is on
print(100 in lista_teste_op)
# Out:
# True

# %% [markdown]
# ## Built-in function

# %%
# Function len() return the lenght of the list
len(lista_teste_op)
# Out:
# 4

# %%
# Function max() return the max value of the list
max(lista_teste_op)
# Out:
# 100

# %%
# Function min() return the lowest value of the list
min(lista_teste_op)
# Out:
# -5

# %%
# Creating
listadomercado2 = ["ovos", "farinha", "leite", "maças"]

# %%
# Add item to it
listadomercado2.append("carne")

# %%
listadomercado2
# Out:
# ['ovos', 'farinha', 'leite', 'maças', 'carne']

# %%
listadomercado2.append("carne")

# %%
listadomercado2
# Out:
# ['ovos', 'farinha', 'leite', 'maças', 'carne', 'carne']

# %%
listadomercado2.count("carne")
# Out:
# 2

# %%
# Creating empty list
a = []

# %%
print(a)
# Out:
# []

# %%
type(a)
# Out:
# list

# %%
a.append(10)

# %%
a
# Out:
# [10]

# %%
a.append(50)

# %%
a
# Out:
# [10, 50]

# %%
old_list = [1,2,5,10]

# %%
new_list = []

# %%
# Copying items
for item in old_list:
    new_list.append(item)

# %%
new_list
# Out:
# [1, 2, 5, 10]

# %%
c = [20,30]

# %%
c.append(60)

# %%
c.append(70)

# %%
c
# Out:
# [20, 30, 60, 70]

# %%
c.count(20)
# Out:
# 1

# %%
cidades = ['Recife', 'Manaus', 'Salvador']
cidades.extend(['Fortaleza', 'Palmas'])
print (cidades)
# Out:
# ['Recife', 'Manaus', 'Salvador', 'Fortaleza', 'Palmas']

# %%
cidades.index('Salvador')
# Out:
# 2

# %%
cidades.index('Rio de Janeiro')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-07703d8eb3ea> in <module>
# ----> 1 cidades.index('Rio de Janeiro')
#
# ValueError: 'Rio de Janeiro' is not in list

# %%
cidades
# Out:
# ['Recife', 'Manaus', 'Salvador', 'Fortaleza', 'Palmas']

# %%
cidades.insert(2, 110)

# %%
cidades
# Out:
# ['Recife', 'Manaus', 110, 'Salvador', 'Fortaleza', 'Palmas']

# %%
# Removing an item
cidades.remove(110)

# %%
cidades
# Out:
# ['Recife', 'Manaus', 'Salvador', 'Fortaleza', 'Palmas']

# %%
# List backwards
cidades.reverse()

# %%
cidades
# Out:
# ['Palmas', 'Fortaleza', 'Salvador', 'Manaus', 'Recife']

# %%
x = [3, 4, 2, 1]

# %%
x
# Out:
# [3, 4, 2, 1]

# %%
# Ordering a list
x.sort()

# %%
x
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## Dictionaries

# %%
# This is a list
estudantes_lst = ["Mateus", 24, "Fernanda", 22, "Tamires", 26, "Cristiano", 25]

# %%
estudantes_lst
# Out:
# ['Mateus', 24, 'Fernanda', 22, 'Tamires', 26, 'Cristiano', 25]

# %%
# This is a dictionary
estudantes_dict = {"Mateus":24, "Fernanda":22, "Tamires":26, "Cristiano":25}

# %%
estudantes_dict
# Out:
# {'Mateus': 24, 'Fernanda': 22, 'Tamires': 26, 'Cristiano': 25}

# %%
estudantes_dict["Mateus"]
# Out:
# 24

# %%
estudantes_dict["Pedro"] = 23

# %%
estudantes_dict["Pedro"]
# Out:
# 23

# %%
estudantes_dict["Tamires"]
# Out:
# 26

# %%
estudantes_dict.clear()

# %%
estudantes_dict
# Out:
# {}

# %%
del estudantes_dict

# %%
estudantes_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-29b87ec1321c> in <module>
# ----> 1 estudantes_dict
#
# NameError: name 'estudantes_dict' is not defined

# %%
estudantes = {"Mateus":24, "Fernanda":22, "Tamires":26, "Cristiano":25}

# %%
estudantes
# Out:
# {'Mateus': 24, 'Fernanda': 22, 'Tamires': 26, 'Cristiano': 25}

# %%
len(estudantes)
# Out:
# 4

# %%
estudantes.keys()
# Out:
# dict_keys(['Mateus', 'Fernanda', 'Tamires', 'Cristiano'])

# %%
estudantes.values()
# Out:
# dict_values([24, 22, 26, 25])

# %%
estudantes.items()
# Out:
# dict_items([('Mateus', 24), ('Fernanda', 22), ('Tamires', 26), ('Cristiano', 25)])

# %%
estudantes2 = {"Maria":27, "Erika":28, "Milton":26}

# %%
estudantes2
# Out:
# {'Maria': 27, 'Erika': 28, 'Milton': 26}

# %%
estudantes.update(estudantes2)

# %%
estudantes
# Out:
# {'Mateus': 24,
#  'Fernanda': 22,
#  'Tamires': 26,
#  'Cristiano': 25,
#  'Maria': 27,
#  'Erika': 28,
#  'Milton': 26}

# %%
dic1 = {}

# %%
dic1
# Out:
# {}

# %%
dic1["key_one"] = 2

# %%
print(dic1)
# Out:
# {'key_one': 2}

# %%
dic1[10] = 5

# %%
dic1
# Out:
# {'key_one': 2, 10: 5}

# %%
dic1[8.2] = "Python"

# %%
dic1
# Out:
# {'key_one': 2, 10: 5, 8.2: 'Python'}

# %%
dic1["teste"] = 5

# %%
dic1
# Out:
# {'key_one': 2, 10: 5, 8.2: 'Python', 'teste': 5}

# %%
dict1 = {}

# %%
dict1
# Out:
# {}

# %%
dict1["teste"] = 10

# %%
dict1["key"] = "teste"

# %%
# The key and value could be the same, but represent different stuff
dict1
# Out:
# {'teste': 10, 'key': 'teste'}

# %%
dict2 = {}

# %%
dict2["key1"] = "Big Data"

# %%
dict2["key2"] = 10

# %%
dict2["key3"] = 5.6

# %%
dict2
# Out:
# {'key1': 'Big Data', 'key2': 10, 'key3': 5.6}

# %%
a = dict2["key1"]

# %%
b = dict2["key2"]

# %%
c = dict2["key3"]

# %%
a, b, c
# Out:
# ('Big Data', 10, 5.6)

# %%
# Dictionary of list
dict3 = {'key1':1230,'key2':[22,453,73.4],'key3':['leite','maça','batata']}

# %%
dict3
# Out:
# {'key1': 1230, 'key2': [22, 453, 73.4], 'key3': ['leite', 'maça', 'batata']}

# %%
dict3['key2']
# Out:
# [22, 453, 73.4]

# %%
# Getting an item of the list, inside the dictionary
dict3['key3'][0].upper()
# Out:
# 'LEITE'

# %%
# Operations with items of the list, inside the dictionary
var1 = dict3['key2'][0] - 2

# %%
var1
# Out:
# 20

# %%
# Two operations, same command, to update an item inside the list
dict3['key2'][0] -= 2

# %%
dict3
# Out:
# {'key1': 1230, 'key2': [20, 453, 73.4], 'key3': ['leite', 'maça', 'batata']}

# %% [markdown]
# ### Creating nested dicts

# %%
# Nested dicts
dict_aninhado = {'key1':{'key2_aninhada':{'key3_aninhada':'Dict aninhado em Python'}}}

# %%
dict_aninhado
# Out:
# {'key1': {'key2_aninhada': {'key3_aninhada': 'Dict aninhado em Python'}}}

# %%
dict_aninhado['key1']['key2_aninhada']['key3_aninhada']
# Out:
# 'Dict aninhado em Python'

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
